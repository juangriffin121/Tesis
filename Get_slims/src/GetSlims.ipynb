# %%
import Bio.SeqIO
import pandas as pd
import re

# %%
class Protein:
    def __init__(self,unaligned_path,aligned_path,query,myseq):
        self.unaligned_path = unaligned_path
        self.aligned_path = aligned_path
        self.query = query
        self.myseq = myseq
        unaligned_dict = {}
        for sequence in Bio.SeqIO.parse(self.unaligned_path, "fasta"):
            unaligned_dict[sequence.id] = sequence.seq
        self.unaligned_dict = unaligned_dict
        aligned_dict = {}
        for sequence in Bio.SeqIO.parse(self.aligned_path, "fasta"):
            aligned_dict[sequence.id] = sequence.seq
        self.aligned_dict = aligned_dict
    def __repr__(self):
        return f'unaligned_path : {self.unaligned_path} \naligned_path : {self.aligned_path} \nquery : {self.query} \nmyseq : {self.myseq}'

# %%
App1 = {'unaligned' : '../raw/App_all_seqs2.txt',
      'aligned' : '../processed/aln-App.txt',
      'query' : 'YTSI',
       'myseq' : 'sp|P05067|A4_HUMAN'}
App2 = {'unaligned' : '../raw/App_all_seqs2.txt',
      'aligned' : '../processed/aln-App.txt',
      'query' : 'YENPTY',
       'myseq' : 'sp|P05067|A4_HUMAN'}
CsgA = {'unaligned' : '../raw/CsgA_all_seqs2.txt',
      'aligned' : '../processed/aln-CsgA.txt',
      'query' : 'VVPQYG',
       'myseq' : 'sp|P28307|CSGA_ECOLI'}
Bap1 = {'unaligned' : '../raw/Bap_all_seqs2.txt',
      'aligned' : '../processed/aln-Bap.txt',
      'query' : 'DYDKDGLLDRYER',
       'myseq' : 'tr|Q79LN3|Q79LN3_STAAU'}
Bap2 = {'unaligned' : '../raw/Bap_all_seqs2.txt',
      'aligned' : '../processed/aln-Bap.txt',
      'query' : 'DTDGDGKNDGDEV',
       'myseq' : 'tr|Q79LN3|Q79LN3_STAAU'}

# %%
App1 = Protein(App1['unaligned'],App1['aligned'],App1['query'],App1['myseq'])

# %%
App2 = Protein(App2['unaligned'],App2['aligned'],App2['query'],App2['myseq'])

# %%
CsgA = Protein(CsgA['unaligned'],CsgA['aligned'],CsgA['query'],CsgA['myseq'])

# %%
Bap1 = Protein(Bap1['unaligned'],Bap1['aligned'],Bap1['query'],Bap1['myseq'])

# %%
Bap2 = Protein(Bap2['unaligned'],Bap2['aligned'],Bap2['query'],Bap2['myseq'])

# %%
prots = {
    'Bap1' : Bap1,
    'Bap2' : Bap2,
    'App1' : App1,
    'App2' : App2,
    'CsgA' : CsgA
}

# %%
class_df = pd.read_csv('../raw/elm_classes.tsv','\t')
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3331: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cand_df = pd.read_html('http://elm.eu.org/elms/candidates')[1]

# %%
cand_dict = {}
for element in cand_df.transpose():
    candidate = cand_df.transpose()[element]
    Regex = candidate['Model']
    ID = candidate['Identifier']
    try:
        print('reads wrong',ID,cand_dict[ID],Regex)
    except:
        cand_dict[ID] = Regex
new_cand_dict = {}
for ID in cand_dict:
    Regex = cand_dict[ID]
    try:
        pattern = re.compile(fr'{Regex}')
        new_cand_dict[ID] =  Regex
    except Exception as e:
        print(ID,Regex,e)
cand_dict = new_cand_dict
# Out:
# reads wrong LIG_VCP_VBM_2 [MILVAK][RK][^P][^P]R[LFWE][^P][^P][FLI][^P] nan
# LIG_RCD1_1 [DE].{1,2)}[YF].{1,4}[DE]L unbalanced parenthesis at position 9
# LIG_Menin_MBM_1 ...R{0,2)FP[GA].P unbalanced parenthesis at position 8
# LIG_SUFU_Gli_1 [CY]GH[LF} unterminated character set at position 6
# <ipython-input-258-89ee6ad923bb>:14: FutureWarning: Possible nested set at position 19
#   pattern = re.compile(fr'{Regex}')

# %%
class_dict = {}
for element in class_df.transpose():
    candidate = class_df.transpose()[element]
    Regex = candidate['Regex']
    ID = candidate['ELMIdentifier']
    try:
        print('reads wrong',ID,class_dict[ID],Regex)
    except:
        class_dict[ID] = Regex

# %%
def get_aln_query_span(prot):
    aln_pos_dict = {}
    query = prot.query
    myseqID = prot.myseq
    myseq_unaln = prot.unaligned_dict[myseqID]
    myseq_aln = prot.aligned_dict[myseqID]
    j = 0
    for i,letter in enumerate(myseq_aln):
        if letter != '-':
            aln_pos_dict[j] = i
            j += 1
    query_span = (aln_pos_dict[myseq_unaln.find(query)],aln_pos_dict[myseq_unaln.find(query) + len(query)])
    return query_span

# %%
#{prot:{regex:{seq:[match1,match2...]}}}
def get_classes(prot):
    regex_dict = {}
    myseqID = prot.myseq
    myseq_unaln = prot.unaligned_dict[myseqID]
    myseq_aln = prot.aligned_dict[myseqID]
    query_span = get_aln_query_span(prot)
    for classID in class_dict:
        Regex = class_dict[classID]
        pattern = re.compile(fr'{Regex}')
        sequence_dict = {}
        for seqID in prot.aligned_dict:
            seq = str(prot.aligned_dict[seqID])
            long_query = seq[query_span[0]-5:query_span[1]+5]
            short_query = seq[query_span[0]:query_span[1]]
            matches = pattern.finditer(long_query)
            true_matches = []
            for match in matches:
                match = long_query[match.span()[0]:match.span()[1]]
                if match.find(short_query) != -1:
                    true_matches.append(match)
            sequence_dict[seqID] = true_matches
        regex_dict[classID] = {'sequences' : sequence_dict,'pattern' : Regex}
    filtered_regex_dict = {}
    for regex in regex_dict:
        filtered_sequence_dict = {}
        sequence_dict = regex_dict[regex]['sequences']
        for seq in sequence_dict:
            matches = sequence_dict[seq]
            if len(matches) != 0:
                filtered_sequence_dict[seq] = matches
        if len(filtered_sequence_dict) != 0:
            filtered_regex_dict[regex] = filtered_sequence_dict
    return filtered_regex_dict

# %%
def get_candidates(prot):
    regex_dict = {}
    myseqID = prot.myseq
    myseq_unaln = prot.unaligned_dict[myseqID]
    myseq_aln = prot.aligned_dict[myseqID]
    query_span = get_aln_query_span(prot)
    for candID in cand_dict:
        Regex = cand_dict[candID]
        pattern = re.compile(fr'{Regex}')
        sequence_dict = {}
        for seqID in prot.aligned_dict:
            seq = str(prot.aligned_dict[seqID])
            long_query = seq[query_span[0]-5:query_span[1]+5]
            short_query = seq[query_span[0]:query_span[1]]
            matches = pattern.finditer(long_query)
            true_matches = []
            for match in matches:
                match = long_query[match.span()[0]:match.span()[1]]
                if match.find(short_query) != -1:
                    true_matches.append(match)
            sequence_dict[seqID] = true_matches
        regex_dict[candID] = {'sequences' : sequence_dict,'pattern' : Regex}
    filtered_regex_dict = {}
    for regex in regex_dict:
        filtered_sequence_dict = {}
        sequence_dict = regex_dict[regex]['sequences']
        for seq in sequence_dict:
            matches = sequence_dict[seq]
            if len(matches) != 0:
                filtered_sequence_dict[seq] = matches
        if len(filtered_sequence_dict) != 0:
            filtered_regex_dict[regex] = filtered_sequence_dict
    return filtered_regex_dict

# %%
full_dict = {}
regex_name_dict = {}
for name in prots:
    print(name)
    prot = prots[name]
    regex_name_dict[name] = {}
    classes_dict = get_classes(prot)
    for regex in classes_dict:
        try:
            regex_name_dict[name]['classes'].append(regex)
        except:
            regex_name_dict[name]['classes'] = [regex]
    candidates_dict = get_candidates(prot)
    for regex in candidates_dict:
        try:
            regex_name_dict[name]['candidates'].append(regex)
        except:
            regex_name_dict[name]['candidates'] = [regex]
    full_dict[name] = {'classes':classes_dict,'candidates':candidates_dict}
# Out:
# Bap1
# Bap2
# App1
# App2
# <ipython-input-262-a0660508e81e>:9: FutureWarning: Possible nested set at position 19
#   pattern = re.compile(fr'{Regex}')
# CsgA

# %%
full_dict
# Out:
# {'Bap1': {'classes': {}, 'candidates': {}},
#  'Bap2': {'classes': {}, 'candidates': {}},
#  'App1': {'classes': {'DOC_MAPK_gen_1': {'XP_028835854.1': ['RKKQYMSI']},
#    'DOC_WW_Pin1_4': {'XP_001601635.2': ['SARSPH'],
#     'XP_046750444.1': ['SARSPH'],
#     'XP_046432224.1': ['SARSPH'],
#     'XP_011148932.1': ['SARSPH'],
#     'XP_011639016.1': ['SARSPH'],
#     'XP_011252362.1': ['SARSPH'],
#     'XP_043288438.1': ['SARSPH'],
#     'XP_044583405.1': ['SARSPH']},
#    'LIG_14-3-3_CanoR_1': {'XP_001601635.2': ['RRSARSP'],
#     'XP_046750444.1': ['RRSARSP'],
#     'XP_046432224.1': ['RRSARSP'],
#     'XP_011148932.1': ['RRSARSP'],
#     'XP_011639016.1': ['RRSARSP'],
#     'XP_011252362.1': ['RRSARSP'],
#     'XP_043288438.1': ['RRSARSP'],
#     'XP_044583405.1': ['RRSARSP']},
#    'LIG_SH2_CRK': {'sp|P05067|A4_HUMAN': ['YTSIH'],
#     'XP_028835854.1': ['YMSIH'],
#     'XP_043875633.1': ['YTSIH'],
#     'XP_034431105.1': ['YTSIH'],
#     'XP_030613788.1': ['YTSIH'],
#     'XP_022051540.2': ['YTSIH'],
#     'XP_018527544.1': ['YTSIH'],
#     'XP_018527459.1': ['YTSIH'],
#     'XP_042282586.1': ['YTSIH'],
#     'XP_044072518.1': ['YTSIH'],
#     'XP_033833649.1': ['YTSIH'],
#     'XP_029030763.1': ['YTSIH'],
#     'XP_030600646.1': ['YTSIH'],
#     'XP_030600638.1': ['YTSIH'],
#     'XP_029941707.1': ['YTSIH'],
#     'XP_044043247.1': ['YTSIH'],
#     'XP_038574583.1': ['YTSIH'],
#     'XP_031438672.1': ['YTSIH'],
#     'XP_041935309.1': ['YTSIH'],
#     'XP_043104465.1': ['YTSIH'],
#     'XP_036445455.1': ['YTSIH'],
#     'XP_016096102.1': ['YTSIH'],
#     'XP_026861393.2': ['YTSIH'],
#     'XP_020360042.1': ['YTSIH'],
#     'XP_046178998.1': ['YTSIH'],
#     'XP_029596311.1': ['YTSIH'],
#     'XP_035610824.1': ['YTSIH'],
#     'XP_021464640.2': ['YTSIH'],
#     'XP_036400640.1': ['YTSIH'],
#     'XP_035249082.1': ['YTSIH']},
#    'LIG_SH2_STAT5': {'sp|P05067|A4_HUMAN': ['YTSI'],
#     'XP_043875633.1': ['YTSI'],
#     'XP_034431105.1': ['YTSI'],
#     'XP_030613788.1': ['YTSI'],
#     'XP_022051540.2': ['YTSI'],
#     'XP_018527544.1': ['YTSI'],
#     'XP_018527459.1': ['YTSI'],
#     'XP_042282586.1': ['YTSI'],
#     'XP_044072518.1': ['YTSI'],
#     'XP_033833649.1': ['YTSI'],
#     'XP_029030763.1': ['YTSI'],
#     'XP_030600646.1': ['YTSI'],
#     'XP_030600638.1': ['YTSI'],
#     'XP_029941707.1': ['YTSI'],
#     'XP_044043247.1': ['YTSI'],
#     'XP_038574583.1': ['YTSI'],
#     'XP_031438672.1': ['YTSI'],
#     'XP_041935309.1': ['YTSI'],
#     'XP_043104465.1': ['YTSI'],
#     'XP_036445455.1': ['YTSI'],
#     'XP_016096102.1': ['YTSI'],
#     'XP_026861393.2': ['YTSI'],
#     'XP_020360042.1': ['YTSI'],
#     'XP_046178998.1': ['YTSI'],
#     'XP_029596311.1': ['YTSI'],
#     'XP_035610824.1': ['YTSI'],
#     'XP_021464640.2': ['YTSI'],
#     'XP_036400640.1': ['YTSI'],
#     'XP_035249082.1': ['YTSI']},
#    'MOD_CK1_1': {'XP_023330436.1': ['SRYSHQQ'],
#     'XP_001601635.2': ['SARSPHS'],
#     'XP_046750444.1': ['SARSPHS'],
#     'XP_046432224.1': ['SARSPHS'],
#     'XP_011148932.1': ['SARSPHS'],
#     'XP_011639016.1': ['SARSPHS'],
#     'XP_011252362.1': ['SARSPHS'],
#     'XP_043288438.1': ['SARSPHS'],
#     'XP_044583405.1': ['SARSPHS']},
#    'MOD_GSK3_1': {'XP_023330436.1': ['RRRTSRYS']},
#    'MOD_N-GLC_1': {'XP_036396035.1': ['QNTSIH']},
#    'MOD_Plk_1': {'XP_036396035.1': ['QNTSIH-']},
#    'MOD_ProDKin_1': {'XP_001601635.2': ['SARSPHS'],
#     'XP_046750444.1': ['SARSPHS'],
#     'XP_046432224.1': ['SARSPHS'],
#     'XP_011148932.1': ['SARSPHS'],
#     'XP_011639016.1': ['SARSPHS'],
#     'XP_011252362.1': ['SARSPHS'],
#     'XP_043288438.1': ['SARSPHS'],
#     'XP_044583405.1': ['SARSPHS']},
#    'TRG_ENDOCYTIC_2': {'sp|P05067|A4_HUMAN': ['YTSI'],
#     'XP_028835854.1': ['YMSI'],
#     'XP_043875633.1': ['YTSI'],
#     'XP_034431105.1': ['YTSI'],
#     'XP_030613788.1': ['YTSI'],
#     'XP_022051540.2': ['YTSI'],
#     'XP_018527544.1': ['YTSI'],
#     'XP_018527459.1': ['YTSI'],
#     'XP_042282586.1': ['YTSI'],
#     'XP_044072518.1': ['YTSI'],
#     'XP_033833649.1': ['YTSI'],
#     'XP_029030763.1': ['YTSI'],
#     'XP_030600646.1': ['YTSI'],
#     'XP_030600638.1': ['YTSI'],
#     'XP_029941707.1': ['YTSI'],
#     'XP_044043247.1': ['YTSI'],
#     'XP_038574583.1': ['YTSI'],
#     'XP_031438672.1': ['YTSI'],
#     'XP_041935309.1': ['YTSI'],
#     'XP_043104465.1': ['YTSI'],
#     'XP_036445455.1': ['YTSI'],
#     'XP_016096102.1': ['YTSI'],
#     'XP_026861393.2': ['YTSI'],
#     'XP_020360042.1': ['YTSI'],
#     'XP_046178998.1': ['YTSI'],
#     'XP_029596311.1': ['YTSI'],
#     'XP_035610824.1': ['YTSI'],
#     'XP_021464640.2': ['YTSI'],
#     'XP_036400640.1': ['YTSI'],
#     'XP_035249082.1': ['YTSI']}},
#   'candidates': {'LIG_SH2_IID': {'sp|P05067|A4_HUMAN': ['YTSI'],
#     'XP_028835854.1': ['YMSI'],
#     'XP_043875633.1': ['YTSI'],
#     'XP_034431105.1': ['YTSI'],
#     'XP_030613788.1': ['YTSI'],
#     'XP_022051540.2': ['YTSI'],
#     'XP_018527544.1': ['YTSI'],
#     'XP_018527459.1': ['YTSI'],
#     'XP_042282586.1': ['YTSI'],
#     'XP_044072518.1': ['YTSI'],
#     'XP_033833649.1': ['YTSI'],
#     'XP_029030763.1': ['YTSI'],
#     'XP_030600646.1': ['YTSI'],
#     'XP_030600638.1': ['YTSI'],
#     'XP_029941707.1': ['YTSI'],
#     'XP_044043247.1': ['YTSI'],
#     'XP_038574583.1': ['YTSI'],
#     'XP_031438672.1': ['YTSI'],
#     'XP_041935309.1': ['YTSI'],
#     'XP_043104465.1': ['YTSI'],
#     'XP_036445455.1': ['YTSI'],
#     'XP_016096102.1': ['YTSI'],
#     'XP_026861393.2': ['YTSI'],
#     'XP_020360042.1': ['YTSI'],
#     'XP_046178998.1': ['YTSI'],
#     'XP_029596311.1': ['YTSI'],
#     'XP_035610824.1': ['YTSI'],
#     'XP_021464640.2': ['YTSI'],
#     'XP_036400640.1': ['YTSI'],
#     'XP_035249082.1': ['YTSI']},
#    'LIG_SH2_IIC': {'sp|P05067|A4_HUMAN': ['YTSI'],
#     'XP_028835854.1': ['YMSI'],
#     'XP_043875633.1': ['YTSI'],
#     'XP_034431105.1': ['YTSI'],
#     'XP_030613788.1': ['YTSI'],
#     'XP_022051540.2': ['YTSI'],
#     'XP_018527544.1': ['YTSI'],
#     'XP_018527459.1': ['YTSI'],
#     'XP_042282586.1': ['YTSI'],
#     'XP_044072518.1': ['YTSI'],
#     'XP_033833649.1': ['YTSI'],
#     'XP_029030763.1': ['YTSI'],
#     'XP_030600646.1': ['YTSI'],
#     'XP_030600638.1': ['YTSI'],
#     'XP_029941707.1': ['YTSI'],
#     'XP_044043247.1': ['YTSI'],
#     'XP_038574583.1': ['YTSI'],
#     'XP_031438672.1': ['YTSI'],
#     'XP_041935309.1': ['YTSI'],
#     'XP_043104465.1': ['YTSI'],
#     'XP_036445455.1': ['YTSI'],
#     'XP_016096102.1': ['YTSI'],
#     'XP_026861393.2': ['YTSI'],
#     'XP_020360042.1': ['YTSI'],
#     'XP_046178998.1': ['YTSI'],
#     'XP_029596311.1': ['YTSI'],
#     'XP_035610824.1': ['YTSI'],
#     'XP_021464640.2': ['YTSI'],
#     'XP_036400640.1': ['YTSI'],
#     'XP_035249082.1': ['YTSI']},
#    'LIG_SH2_IB': {'sp|P05067|A4_HUMAN': ['YTSI'],
#     'XP_028835854.1': ['YMSI'],
#     'XP_043875633.1': ['YTSI'],
#     'XP_034431105.1': ['YTSI'],
#     'XP_030613788.1': ['YTSI'],
#     'XP_022051540.2': ['YTSI'],
#     'XP_018527544.1': ['YTSI'],
#     'XP_018527459.1': ['YTSI'],
#     'XP_042282586.1': ['YTSI'],
#     'XP_044072518.1': ['YTSI'],
#     'XP_033833649.1': ['YTSI'],
#     'XP_029030763.1': ['YTSI'],
#     'XP_030600646.1': ['YTSI'],
#     'XP_030600638.1': ['YTSI'],
#     'XP_029941707.1': ['YTSI'],
#     'XP_044043247.1': ['YTSI'],
#     'XP_038574583.1': ['YTSI'],
#     'XP_031438672.1': ['YTSI'],
#     'XP_041935309.1': ['YTSI'],
#     'XP_043104465.1': ['YTSI'],
#     'XP_036445455.1': ['YTSI'],
#     'XP_016096102.1': ['YTSI'],
#     'XP_026861393.2': ['YTSI'],
#     'XP_020360042.1': ['YTSI'],
#     'XP_046178998.1': ['YTSI'],
#     'XP_029596311.1': ['YTSI'],
#     'XP_035610824.1': ['YTSI'],
#     'XP_021464640.2': ['YTSI'],
#     'XP_036400640.1': ['YTSI'],
#     'XP_035249082.1': ['YTSI']},
#    'LIG_FERM_3': {'sp|P05067|A4_HUMAN': ['KKKQYTSI'],
#     'XP_028835854.1': ['RKKQYMSI'],
#     'XP_043875633.1': ['RKKQYTSI'],
#     'XP_034431105.1': ['RKKQYTSI'],
#     'XP_030613788.1': ['RKKQYTSI'],
#     'XP_022051540.2': ['RKKQYTSI'],
#     'XP_018527544.1': ['RKKQYTSI'],
#     'XP_018527459.1': ['RKKQYTSI'],
#     'XP_042282586.1': ['RKKQYTSI'],
#     'XP_044072518.1': ['RKKQYTSI'],
#     'XP_033833649.1': ['RKKQYTSI'],
#     'XP_029030763.1': ['RKKQYTSI'],
#     'XP_030600646.1': ['RKKQYTSI'],
#     'XP_030600638.1': ['RKKQYTSI'],
#     'XP_029941707.1': ['RKKQYTSI'],
#     'XP_044043247.1': ['RKKQYTSI'],
#     'XP_038574583.1': ['RKKQYTSI'],
#     'XP_031438672.1': ['RKKQYTSI'],
#     'XP_041935309.1': ['RKKQYTSI'],
#     'XP_043104465.1': ['RKKQYTSI'],
#     'XP_036445455.1': ['RKKQYTSI'],
#     'XP_016096102.1': ['RKKQYTSI'],
#     'XP_026861393.2': ['RKKQYTSI'],
#     'XP_020360042.1': ['RKKQYTSI'],
#     'XP_046178998.1': ['RKKQYTSI'],
#     'XP_029596311.1': ['RKKQYTSI'],
#     'XP_035610824.1': ['RKKQYTSI'],
#     'XP_021464640.2': ['RKKQYTSI'],
#     'XP_036400640.1': ['RKNQYTSI'],
#     'XP_035249082.1': ['RKKQYTSI']},
#    'LIG_AIM': {'sp|P05067|A4_HUMAN': ['YTSI'],
#     'XP_028835854.1': ['YMSI'],
#     'XP_043875633.1': ['YTSI'],
#     'XP_034431105.1': ['YTSI'],
#     'XP_030613788.1': ['YTSI'],
#     'XP_022051540.2': ['YTSI'],
#     'XP_018527544.1': ['YTSI'],
#     'XP_018527459.1': ['YTSI'],
#     'XP_042282586.1': ['YTSI'],
#     'XP_044072518.1': ['YTSI'],
#     'XP_033833649.1': ['YTSI'],
#     'XP_029030763.1': ['YTSI'],
#     'XP_030600646.1': ['YTSI'],
#     'XP_030600638.1': ['YTSI'],
#     'XP_029941707.1': ['YTSI'],
#     'XP_044043247.1': ['YTSI'],
#     'XP_038574583.1': ['YTSI'],
#     'XP_031438672.1': ['YTSI'],
#     'XP_041935309.1': ['YTSI'],
#     'XP_043104465.1': ['YTSI'],
#     'XP_036445455.1': ['YTSI'],
#     'XP_016096102.1': ['YTSI'],
#     'XP_026861393.2': ['YTSI'],
#     'XP_020360042.1': ['YTSI'],
#     'XP_046178998.1': ['YTSI'],
#     'XP_029596311.1': ['YTSI'],
#     'XP_035610824.1': ['YTSI'],
#     'XP_021464640.2': ['YTSI'],
#     'XP_036400640.1': ['YTSI'],
#     'XP_035249082.1': ['YTSI']}}},
#  'App2': {'classes': {'LIG_PTB_Apo_2': {'sp|P05067|A4_HUMAN': ['GYENPTYK'],
#     'XP_028835854.1': ['GYENPTYK'],
#     'XP_043875633.1': ['GYENPTYK'],
#     'XP_034431105.1': ['GYENPTYK'],
#     'XP_030613788.1': ['GYENPTYK'],
#     'XP_022051540.2': ['GYENPTYK'],
#     'XP_018527544.1': ['GYENPTYK'],
#     'XP_018527459.1': ['GYENPTYK'],
#     'XP_042282586.1': ['GYENPTYK'],
#     'XP_044072518.1': ['GYENPTYK'],
#     'XP_033833649.1': ['GYENPTYK'],
#     'XP_029030763.1': ['GYENPTYK'],
#     'XP_030600646.1': ['GYENPTYK'],
#     'XP_030600638.1': ['GYENPTYK'],
#     'XP_029941707.1': ['GYENPTYK'],
#     'XP_044043247.1': ['GYENPTYK'],
#     'XP_038574583.1': ['GYENPTYK'],
#     'XP_031438672.1': ['GYENPTYK'],
#     'XP_041935309.1': ['GYENPTYK'],
#     'XP_043104465.1': ['GYENPTYK'],
#     'XP_036445455.1': ['GYENPTYK'],
#     'XP_016096102.1': ['GYENPTYK'],
#     'XP_026861393.2': ['GYENPTYK'],
#     'XP_020360042.1': ['GYENPTYK'],
#     'XP_046178998.1': ['GYENPTYK'],
#     'XP_029596311.1': ['GYENPTYK'],
#     'XP_035610824.1': ['GYENPTYK'],
#     'XP_021464640.2': ['GYENPTYK'],
#     'XP_036400640.1': ['GYENPTYK'],
#     'XP_036396035.1': ['GYENPTYK'],
#     'XP_035249082.1': ['GYENPTYK'],
#     'XP_023330436.1': ['GYENPTYK'],
#     'XP_051174948.1': ['GYENPTYK'],
#     'XP_001601635.2': ['GYENPTYK'],
#     'XP_046750444.1': ['GYENPTYK'],
#     'XP_046432224.1': ['GYENPTYK'],
#     'XP_011148932.1': ['GYENPTYK'],
#     'XP_011639016.1': ['GYENPTYK'],
#     'XP_011252362.1': ['GYENPTYK'],
#     'XP_043288438.1': ['GYENPTYK'],
#     'XP_044583405.1': ['GYENPTYK']},
#    'LIG_PTB_Phospho_1': {'sp|P05067|A4_HUMAN': ['GYENPTY'],
#     'XP_028835854.1': ['GYENPTY'],
#     'XP_043875633.1': ['GYENPTY'],
#     'XP_034431105.1': ['GYENPTY'],
#     'XP_030613788.1': ['GYENPTY'],
#     'XP_022051540.2': ['GYENPTY'],
#     'XP_018527544.1': ['GYENPTY'],
#     'XP_018527459.1': ['GYENPTY'],
#     'XP_042282586.1': ['GYENPTY'],
#     'XP_044072518.1': ['GYENPTY'],
#     'XP_033833649.1': ['GYENPTY'],
#     'XP_029030763.1': ['GYENPTY'],
#     'XP_030600646.1': ['GYENPTY'],
#     'XP_030600638.1': ['GYENPTY'],
#     'XP_029941707.1': ['GYENPTY'],
#     'XP_044043247.1': ['GYENPTY'],
#     'XP_038574583.1': ['GYENPTY'],
#     'XP_031438672.1': ['GYENPTY'],
#     'XP_041935309.1': ['GYENPTY'],
#     'XP_043104465.1': ['GYENPTY'],
#     'XP_036445455.1': ['GYENPTY'],
#     'XP_016096102.1': ['GYENPTY'],
#     'XP_026861393.2': ['GYENPTY'],
#     'XP_020360042.1': ['GYENPTY'],
#     'XP_046178998.1': ['GYENPTY'],
#     'XP_029596311.1': ['GYENPTY'],
#     'XP_035610824.1': ['GYENPTY'],
#     'XP_021464640.2': ['GYENPTY'],
#     'XP_036400640.1': ['GYENPTY'],
#     'XP_036396035.1': ['GYENPTY'],
#     'XP_035249082.1': ['GYENPTY'],
#     'XP_023330436.1': ['GYENPTY'],
#     'XP_051174948.1': ['GYENPTY'],
#     'XP_001601635.2': ['GYENPTY'],
#     'XP_046750444.1': ['GYENPTY'],
#     'XP_046432224.1': ['GYENPTY'],
#     'XP_011148932.1': ['GYENPTY'],
#     'XP_011639016.1': ['GYENPTY'],
#     'XP_011252362.1': ['GYENPTY'],
#     'XP_043288438.1': ['GYENPTY'],
#     'XP_044583405.1': ['GYENPTY']}},
#   'candidates': {'LIG_Caveolin': {'sp|P05067|A4_HUMAN': ['YENPTYKFF'],
#     'XP_028835854.1': ['YENPTYKFF'],
#     'XP_043875633.1': ['YENPTYKFF'],
#     'XP_034431105.1': ['YENPTYKFF'],
#     'XP_030613788.1': ['YENPTYKFF'],
#     'XP_022051540.2': ['YENPTYKFF'],
#     'XP_018527544.1': ['YENPTYKFF'],
#     'XP_018527459.1': ['YENPTYKFF'],
#     'XP_042282586.1': ['YENPTYKFF'],
#     'XP_044072518.1': ['YENPTYKFF'],
#     'XP_033833649.1': ['YENPTYKFF'],
#     'XP_029030763.1': ['YENPTYKFF'],
#     'XP_030600646.1': ['YENPTYKFF'],
#     'XP_030600638.1': ['YENPTYKFF'],
#     'XP_029941707.1': ['YENPTYKFF'],
#     'XP_044043247.1': ['YENPTYKFF'],
#     'XP_038574583.1': ['YENPTYKFF'],
#     'XP_031438672.1': ['YENPTYKFF'],
#     'XP_041935309.1': ['YENPTYKFF'],
#     'XP_043104465.1': ['YENPTYKFF'],
#     'XP_036445455.1': ['YENPTYKFF'],
#     'XP_016096102.1': ['YENPTYKFF'],
#     'XP_026861393.2': ['YENPTYKFF'],
#     'XP_020360042.1': ['YENPTYKFF'],
#     'XP_046178998.1': ['YENPTYKFF'],
#     'XP_029596311.1': ['YENPTYKFF'],
#     'XP_035610824.1': ['YENPTYKFF'],
#     'XP_021464640.2': ['YENPTYKFF'],
#     'XP_036400640.1': ['YENPTYKFF'],
#     'XP_036396035.1': ['YENPTYKFF'],
#     'XP_035249082.1': ['YENPTYKFF'],
#     'XP_023330436.1': ['YENPTYKYF'],
#     'XP_051174948.1': ['YENPTYKYF'],
#     'XP_001601635.2': ['YENPTYKYF'],
#     'XP_046750444.1': ['YENPTYKYF'],
#     'XP_046432224.1': ['YENPTYKYF'],
#     'XP_011148932.1': ['YENPTYKYF'],
#     'XP_011639016.1': ['YENPTYKYF'],
#     'XP_011252362.1': ['YENPTYKYF'],
#     'XP_043288438.1': ['YENPTYKYF'],
#     'XP_044583405.1': ['YENPTYKYF']},
#    'Mod_CDK_Long_2': {'sp|P05067|A4_HUMAN': ['YENPTYK'],
#     'XP_028835854.1': ['YENPTYK'],
#     'XP_043875633.1': ['YENPTYK'],
#     'XP_034431105.1': ['YENPTYK'],
#     'XP_030613788.1': ['YENPTYK'],
#     'XP_022051540.2': ['YENPTYK'],
#     'XP_018527544.1': ['YENPTYK'],
#     'XP_018527459.1': ['YENPTYK'],
#     'XP_042282586.1': ['YENPTYK'],
#     'XP_044072518.1': ['YENPTYK'],
#     'XP_033833649.1': ['YENPTYK'],
#     'XP_029030763.1': ['YENPTYK'],
#     'XP_030600646.1': ['YENPTYK'],
#     'XP_030600638.1': ['YENPTYK'],
#     'XP_029941707.1': ['YENPTYK'],
#     'XP_044043247.1': ['YENPTYK'],
#     'XP_038574583.1': ['YENPTYK'],
#     'XP_031438672.1': ['YENPTYK'],
#     'XP_041935309.1': ['YENPTYK'],
#     'XP_043104465.1': ['YENPTYK'],
#     'XP_036445455.1': ['YENPTYK'],
#     'XP_016096102.1': ['YENPTYK'],
#     'XP_026861393.2': ['YENPTYK'],
#     'XP_020360042.1': ['YENPTYK'],
#     'XP_046178998.1': ['YENPTYK'],
#     'XP_029596311.1': ['YENPTYK'],
#     'XP_035610824.1': ['YENPTYK'],
#     'XP_021464640.2': ['YENPTYK'],
#     'XP_036400640.1': ['YENPTYK'],
#     'XP_036396035.1': ['YENPTYK'],
#     'XP_035249082.1': ['YENPTYK'],
#     'XP_023330436.1': ['YENPTYK'],
#     'XP_051174948.1': ['YENPTYK'],
#     'XP_001601635.2': ['YENPTYK'],
#     'XP_046750444.1': ['YENPTYK'],
#     'XP_046432224.1': ['YENPTYK'],
#     'XP_011148932.1': ['YENPTYK'],
#     'XP_011639016.1': ['YENPTYK'],
#     'XP_011252362.1': ['YENPTYK'],
#     'XP_043288438.1': ['YENPTYK'],
#     'XP_044583405.1': ['YENPTYK']}}},
#  'CsgA': {'classes': {}, 'candidates': {}}}

# %%
print(1)
# Out:
# 1
